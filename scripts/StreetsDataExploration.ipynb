# %% [markdown]
# # Data Exploration - Streets

# %%
import pandas as pd
import numpy as np
import geopandas as gp
import matplotlib.pyplot as plt
#from mpl_toolkits.basemap import Basemap  - TO DO install on system


# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (16,16)

# %%
gp.__version__
# Out:
# '0.1.1'

# %%
# Reading in data

slow_zones = gp.GeoDataFrame.from_file('../data/neighborhood_slow_zones.json')
construction = gp.GeoDataFrame.from_file('../data/street_improvement_projects_2013_to_2015_corridors.json')

# census tracts 2010
ct = gp.GeoDataFrame.from_file('../data/nyct2010_15d/nyct2010.shp')

# %%
ct.plot()

# %%
construction.plot()

# %%
ct.head()
# Out:
#   BoroCT2010 BoroCode       BoroName CDEligibil  CT2010 CTLabel NTACode  \
# 0    5000900        5  Staten Island          I  000900       9    SI22
# 1    5012500        5  Staten Island          I  012500     125    SI22
# 2    5013301        5  Staten Island          E  013301  133.01    SI22
# 3    5019700        5  Staten Island          I  019700     197    SI07
# 4    5006400        5  Staten Island          I  006400      64    SI14
#
#                                      NTAName  PUMA    Shape_Area  \
# 0  West New Brighton-New Brighton-St. George  3903  2.497010e+06
# 1  West New Brighton-New Brighton-St. George  3903  4.954936e+06
# 2  West New Brighton-New Brighton-St. George  3903  7.217847e+05
# 3                                Westerleigh  3903  3.231720e+06
# 4            Grasmere-Arrochar-Ft. Wadsworth  3902  7.643184e+06
#
#      Shape_Leng                                           geometry
# 0   7729.016729  POLYGON ((962269.1260375977 173705.5001831055,...
# ...

# %%
matplotlib.__version__
# Out:
# '1.5.1'
